# %% [markdown]
# # Twitter data
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %% [markdown]
# # Twitter API Access
#
# Twitter implements OAuth 1.0A as its standard authentication mechanism, and in order to use it to make requests to Twitter's API, you'll need to go to https://dev.twitter.com/apps and create a sample application.
#
# Choose any name for your application, write a description and use `http://google.com` for the website.
#
# Under **Key and Access Tokens**, there are four primary identifiers you'll need to note for an OAuth 1.0A workflow:
# * consumer key,
# * consumer secret,
# * access token, and
# * access token secret (Click on Create Access Token to create those).
#
# Note that you will need an ordinary Twitter account in order to login, create an app, and get these credentials.

# %% [markdown]
# The first time you execute the notebook, add all credentials so that you can save them in the `pkl` file, then you can remove the secret keys from the notebook because they will just be loaded from the `pkl` file.
#
# The `pkl` file contains sensitive information that can be used to take control of your twitter acccount, **do not share it**.

# %%
import pickle
import os

# %%
if not os.path.exists('secret_twitter_credentials.pkl'):
    Twitter={}
    Twitter['Consumer Key'] = ''
    Twitter['Consumer Secret'] = ''
    Twitter['Access Token'] = ''
    Twitter['Access Token Secret'] = ''
    with open('secret_twitter_credentials.pkl','wb') as f:
        pickle.dump(Twitter, f)
else:
    Twitter=pickle.load(open('secret_twitter_credentials.pkl','rb'))

# %% [markdown]
# Install the `twitter` package to interface with the Twitter API

# %%
# !pip install twitter
# Out:
# Collecting twitter
#   Downloading https://files.pythonhosted.org/packages/85/e2/f602e3f584503f03e0389491b251464f8ecfe2596ac86e6b9068fe7419d3/twitter-1.18.0-py2.py3-none-any.whl (54kB)
#     100% |████████████████████████████████| 61kB 703kB/s ta 0:00:01
# Installing collected packages: twitter
# Successfully installed twitter-1.18.0

# %% [markdown]
# ## Example 1. Authorizing an application to access Twitter account data

# %%
import twitter

auth = twitter.oauth.OAuth(Twitter['Access Token'],
                           Twitter['Access Token Secret'],
                           Twitter['Consumer Key'],
                           Twitter['Consumer Secret'])

twitter_api = twitter.Twitter(auth=auth)

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print(twitter_api)
# Out:
# <twitter.api.Twitter object at 0x107c0ca58>

# %% [markdown]
# ## Example 2. Retrieving trends

# %% [markdown]
# Twitter identifies locations using the Yahoo! Where On Earth ID.
#
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/
#
# look at the BOSS placefinder here: https://developer.yahoo.com/boss/placefinder/

# %%
WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# %% [markdown]
# Look for the WOEID for [san-diego](http://woeid.rosselliot.co.nz/lookup/san%20diego%20%20ca)
#
# You can change it to another location.

# %%
LOCAL_WOE_ID=718345

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)
local_trends = twitter_api.trends.place(_id=LOCAL_WOE_ID)

# %%
world_trends[:2]
# Out:
# [{'as_of': '2019-01-12T21:12:43Z',
#   'created_at': '2019-01-12T21:07:27Z',
#   'locations': [{'name': 'Worldwide', 'woeid': 1}],
#   'trends': [{'name': '#NXTUKTakeOver',
#     'promoted_content': None,
#     'query': '%23NXTUKTakeOver',
#     'tweet_volume': 46351,
#     'url': 'http://twitter.com/search?q=%23NXTUKTakeOver'},
#    {'name': '#DestinationEurovision',
#     'promoted_content': None,
#     'query': '%23DestinationEurovision',
#     'tweet_volume': 19711,
#     'url': 'http://twitter.com/search?q=%23DestinationEurovision'},
#    {'name': '#cepostaperte',
#     'promoted_content': None,
#     'query': '%23cepostaperte',
#     'tweet_volume': 10506,
#     'url': 'http://twitter.com/search?q=%23cepostaperte'},
#    {'name': '#صندوق_السبع_Momax',
#     'promoted_content': None,
#     'query': '%23%D8%B5%D9%86%D8%AF%D9%88%D9%82_%D8%A7%D9%84%D8%B3%D8%A8%D8%B9_Momax',
#     'tweet_volume': 79979,
#     'url': 'http://twitter.com/search?q=%23%D8%B5%D9%86%D8%AF%D9%88%D9%82_%D8%A7%D9%84%D8%B3%D8%A8%D8%B9_Momax'},
#    {'name': 'Duke',
#     'promoted_content': None,
#     'query': 'Duke',
#     'tweet_volume': 36194,
#     'url': 'http://twitter.com/search?q=Duke'},
#    {'name': '#widm',
#     'promoted_content': None,
#     'query': '%23widm',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23widm'},
#    {'name': 'Willian',
#     'promoted_content': None,
#     'query': 'Willian',
#     'tweet_volume': 42733,
#     'url': 'http://twitter.com/search?q=Willian'},
#    {'name': 'Toni Storm',
#     'promoted_content': None,
#     'query': '%22Toni+Storm%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Toni+Storm%22'},
#    {'name': 'Cam Reddish',
#     'promoted_content': None,
#     'query': '%22Cam+Reddish%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Cam+Reddish%22'},
#    {'name': 'RJ Barrett',
#     'promoted_content': None,
#     'query': '%22RJ+Barrett%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22RJ+Barrett%22'},
#    {'name': 'Julian Castro',
#     'promoted_content': None,
#     'query': '%22Julian+Castro%22',
#     'tweet_volume': 28435,
#     'url': 'http://twitter.com/search?q=%22Julian+Castro%22'},
#    {'name': 'Dick Vitale',
#     'promoted_content': None,
#     'query': '%22Dick+Vitale%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Dick+Vitale%22'},
#    {'name': 'Finn Balor',
#     'promoted_content': None,
#     'query': '%22Finn+Balor%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Finn+Balor%22'},
#    {'name': 'Cutrone',
#     'promoted_content': None,
#     'query': 'Cutrone',
#     'tweet_volume': 11816,
#     'url': 'http://twitter.com/search?q=Cutrone'},
#    {'name': 'Rae Sremmurd',
#     'promoted_content': None,
#     'query': '%22Rae+Sremmurd%22',
#     'tweet_volume': 14443,
#     'url': 'http://twitter.com/search?q=%22Rae+Sremmurd%22'},
#    {'name': 'Newcastle',
#     'promoted_content': None,
#     'query': 'Newcastle',
#     'tweet_volume': 39202,
#     'url': 'http://twitter.com/search?q=Newcastle'},
#    {'name': 'David Luiz',
#     'promoted_content': None,
#     'query': '%22David+Luiz%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22David+Luiz%22'},
#    {'name': 'Florida State',
#     'promoted_content': None,
#     'query': '%22Florida+State%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Florida+State%22'},
#    {'name': 'Chimène Badi',
#     'promoted_content': None,
#     'query': '%22Chim%C3%A8ne+Badi%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Chim%C3%A8ne+Badi%22'},
#    {'name': 'Bilal',
#     'promoted_content': None,
#     'query': 'Bilal',
#     'tweet_volume': 25718,
#     'url': 'http://twitter.com/search?q=Bilal'},
#    {'name': 'Pete Dunne',
#     'promoted_content': None,
#     'query': '%22Pete+Dunne%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Pete+Dunne%22'},
#    {'name': '#BolognaJuve',
#     'promoted_content': None,
#     'query': '%23BolognaJuve',
#     'tweet_volume': 10575,
#     'url': 'http://twitter.com/search?q=%23BolognaJuve'},
#    {'name': '#CHENEW',
#     'promoted_content': None,
#     'query': '%23CHENEW',
#     'tweet_volume': 32996,
#     'url': 'http://twitter.com/search?q=%23CHENEW'},
#    {'name': '#moltalk',
#     'promoted_content': None,
#     'query': '%23moltalk',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23moltalk'},
#    {'name': '#السعوديه_لبنان',
#     'promoted_content': None,
#     'query': '%23%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D9%87_%D9%84%D8%A8%D9%86%D8%A7%D9%86',
#     'tweet_volume': 184101,
#     'url': 'http://twitter.com/search?q=%23%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D9%87_%D9%84%D8%A8%D9%86%D8%A7%D9%86'},
#    {'name': '#Bets10PokerFreerollBinTL',
#     'promoted_content': None,
#     'query': '%23Bets10PokerFreerollBinTL',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23Bets10PokerFreerollBinTL'},
#    {'name': '#40BinÖğrtAtamasıHaktır',
#     'promoted_content': None,
#     'query': '%2340Bin%C3%96%C4%9FrtAtamas%C4%B1Hakt%C4%B1r',
#     'tweet_volume': 82773,
#     'url': 'http://twitter.com/search?q=%2340Bin%C3%96%C4%9FrtAtamas%C4%B1Hakt%C4%B1r'},
#    {'name': '#ChiefsKingdom',
#     'promoted_content': None,
#     'query': '%23ChiefsKingdom',
#     'tweet_volume': 16535,
#     'url': 'http://twitter.com/search?q=%23ChiefsKingdom'},
#    {'name': '#SampdoriaMilan',
#     'promoted_content': None,
#     'query': '%23SampdoriaMilan',
#     'tweet_volume': 12078,
#     'url': 'http://twitter.com/search?q=%23SampdoriaMilan'},
#    {'name': '#INDvsKC',
#     'promoted_content': None,
#     'query': '%23INDvsKC',
#     'tweet_volume': 18855,
#     'url': 'http://twitter.com/search?q=%23INDvsKC'},
#    {'name': '#ukwomenstitle',
#     'promoted_content': None,
#     'query': '%23ukwomenstitle',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23ukwomenstitle'},
#    {'name': '#ÇekeVarsaTümBorçlaraHapis',
#     'promoted_content': None,
#     'query': '%23%C3%87ekeVarsaT%C3%BCmBor%C3%A7laraHapis',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23%C3%87ekeVarsaT%C3%BCmBor%C3%A7laraHapis'},
#    {'name': '#NXTTakeOverBlackpool',
#     'promoted_content': None,
#     'query': '%23NXTTakeOverBlackpool',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23NXTTakeOverBlackpool'},
#    {'name': '#SamsunOrjinCafedeSu8TL',
#     'promoted_content': None,
#     'query': '%23SamsunOrjinCafedeSu8TL',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23SamsunOrjinCafedeSu8TL'},
#    {'name': '#EnBüyükBelaSevgisizlik',
#     'promoted_content': None,
#     'query': '%23EnB%C3%BCy%C3%BCkBelaSevgisizlik',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23EnB%C3%BCy%C3%BCkBelaSevgisizlik'},
#    {'name': '#Its2019andWeStillCant',
#     'promoted_content': None,
#     'query': '%23Its2019andWeStillCant',
#     'tweet_volume': 15526,
#     'url': 'http://twitter.com/search?q=%23Its2019andWeStillCant'},
#    {'name': '#NXTUKTagTitles',
#     'promoted_content': None,
#     'query': '%23NXTUKTagTitles',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23NXTUKTagTitles'},
#    {'name': '#CoppaItalia',
#     'promoted_content': None,
#     'query': '%23CoppaItalia',
#     'tweet_volume': 12329,
#     'url': 'http://twitter.com/search?q=%23CoppaItalia'},
#    {'name': '#بالوقت_هذا_احتاج',
#     'promoted_content': None,
#     'query': '%23%D8%A8%D8%A7%D9%84%D9%88%D9%82%D8%AA_%D9%87%D8%B0%D8%A7_%D8%A7%D8%AD%D8%AA%D8%A7%D8%AC',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23%D8%A8%D8%A7%D9%84%D9%88%D9%82%D8%AA_%D9%87%D8%B0%D8%A7_%D8%A7%D8%AD%D8%AA%D8%A7%D8%AC'},
#    {'name': '#HalkEytDiyor',
#     'promoted_content': None,
#     'query': '%23HalkEytDiyor',
#     'tweet_volume': 62338,
#     'url': 'http://twitter.com/search?q=%23HalkEytDiyor'},
#    {'name': '#LetsRoll',
#     'promoted_content': None,
#     'query': '%23LetsRoll',
#     'tweet_volume': 19890,
#     'url': 'http://twitter.com/search?q=%23LetsRoll'},
#    {'name': '#OGCNFCGB',
#     'promoted_content': None,
#     'query': '%23OGCNFCGB',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23OGCNFCGB'},
#    {'name': '#L6Nacuerdos',
#     'promoted_content': None,
#     'query': '%23L6Nacuerdos',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23L6Nacuerdos'},
#    {'name': '#نتايج_الثانويه_العامه',
#     'promoted_content': None,
#     'query': '%23%D9%86%D8%AA%D8%A7%D9%8A%D8%AC_%D8%A7%D9%84%D8%AB%D8%A7%D9%86%D9%88%D9%8A%D9%87_%D8%A7%D9%84%D8%B9%D8%A7%D9%85%D9%87',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23%D9%86%D8%AA%D8%A7%D9%8A%D8%AC_%D8%A7%D9%84%D8%AB%D8%A7%D9%86%D9%88%D9%8A%D9%87_%D8%A7%D9%84%D8%B9%D8%A7%D9%85%D9%87'},
#    {'name': '#ToniTime',
#     'promoted_content': None,
#     'query': '%23ToniTime',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23ToniTime'},
#    {'name': '#BabyOneMoreTime20',
#     'promoted_content': None,
#     'query': '%23BabyOneMoreTime20',
#     'tweet_volume': 17110,
#     'url': 'http://twitter.com/search?q=%23BabyOneMoreTime20'},
#    {'name': '#TeslaTRTBelgeselde',
#     'promoted_content': None,
#     'query': '%23TeslaTRTBelgeselde',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23TeslaTRTBelgeselde'},
#    {'name': '#1YearOfCamila',
#     'promoted_content': None,
#     'query': '%231YearOfCamila',
#     'tweet_volume': 97374,
#     'url': 'http://twitter.com/search?q=%231YearOfCamila'},
#    {'name': '#EstoyConGuaido',
#     'promoted_content': None,
#     'query': '%23EstoyConGuaido',
#     'tweet_volume': 11952,
#     'url': 'http://twitter.com/search?q=%23EstoyConGuaido'},
#    {'name': '#JinGaveMeWings',
#     'promoted_content': None,
#     'query': '%23JinGaveMeWings',
#     'tweet_volume': 118216,
#     'url': 'http://twitter.com/search?q=%23JinGaveMeWings'}]}]

# %%
trends=local_trends
print(type(trends))
print(list(trends[0].keys()))
print(trends[0]['trends'])
# Out:
# <class 'twitter.api.TwitterListResponse'>
# ['trends', 'as_of', 'created_at', 'locations']
# [{'name': '#cepostaperte', 'url': 'http://twitter.com/search?q=%23cepostaperte', 'promoted_content': None, 'query': '%23cepostaperte', 'tweet_volume': 10506}, {'name': '#BolognaJuve', 'url': 'http://twitter.com/search?q=%23BolognaJuve', 'promoted_content': None, 'query': '%23BolognaJuve', 'tweet_volume': 10575}, {'name': '#SampdoriaMilan', 'url': 'http://twitter.com/search?q=%23SampdoriaMilan', 'promoted_content': None, 'query': '%23SampdoriaMilan', 'tweet_volume': 12078}, {'name': 'Ricky Martin', 'url': 'http://twitter.com/search?q=%22Ricky+Martin%22', 'promoted_content': None, 'query': '%22Ricky+Martin%22', 'tweet_volume': None}, {'name': '#Cutrone', 'url': 'http://twitter.com/search?q=%23Cutrone', 'promoted_content': None, 'query': '%23Cutrone', 'tweet_volume': None}, {'name': '#SampMilan', 'url': 'http://twitter.com/search?q=%23SampMilan', 'promoted_content': None, 'query': '%23SampMilan', 'tweet_volume': None}, {'name': 'Conti', 'url': 'http://twitter.com/search?q=Conti', 'promoted_content': None, 'query': 'Conti', 'tweet_volume': None}, {'name': 'Maria', 'url': 'http://twitter.com/search?q=Maria', 'promoted_content': None, 'query': 'Maria', 'tweet_volume': 184741}, {'name': 'De Sciglio', 'url': 'http://twitter.com/search?q=%22De+Sciglio%22', 'promoted_content': None, 'query': '%22De+Sciglio%22', 'tweet_volume': None}, {'name': 'Olga Fernando', 'url': 'http://twitter.com/search?q=%22Olga+Fernando%22', 'promoted_content': None, 'query': '%22Olga+Fernando%22', 'tweet_volume': None}, {'name': 'Reina', 'url': 'http://twitter.com/search?q=Reina', 'promoted_content': None, 'query': 'Reina', 'tweet_volume': 41483}, {'name': 'Douglas Costa', 'url': 'http://twitter.com/search?q=%22Douglas+Costa%22', 'promoted_content': None, 'query': '%22Douglas+Costa%22', 'tweet_volume': None}, {'name': 'Alexandra', 'url': 'http://twitter.com/search?q=Alexandra', 'promoted_content': None, 'query': 'Alexandra', 'tweet_volume': 10405}, {'name': 'Higuain', 'url': 'http://twitter.com/search?q=Higuain', 'promoted_content': None, 'query': 'Higuain', 'tweet_volume': None}, {'name': 'Patrick', 'url': 'http://twitter.com/search?q=Patrick', 'promoted_content': None, 'query': 'Patrick', 'tweet_volume': 60561}, {'name': 'Paquetà', 'url': 'http://twitter.com/search?q=Paquet%C3%A0', 'promoted_content': None, 'query': 'Paquet%C3%A0', 'tweet_volume': 14450}, {'name': 'Spinazzola', 'url': 'http://twitter.com/search?q=Spinazzola', 'promoted_content': None, 'query': 'Spinazzola', 'tweet_volume': None}, {'name': 'saponara', 'url': 'http://twitter.com/search?q=saponara', 'promoted_content': None, 'query': 'saponara', 'tweet_volume': None}, {'name': 'Borini', 'url': 'http://twitter.com/search?q=Borini', 'promoted_content': None, 'query': 'Borini', 'tweet_volume': None}, {'name': 'Abate', 'url': 'http://twitter.com/search?q=Abate', 'promoted_content': None, 'query': 'Abate', 'tweet_volume': None}, {'name': 'Chiellini', 'url': 'http://twitter.com/search?q=Chiellini', 'promoted_content': None, 'query': 'Chiellini', 'tweet_volume': None}, {'name': 'Calhanoglu', 'url': 'http://twitter.com/search?q=Calhanoglu', 'promoted_content': None, 'query': 'Calhanoglu', 'tweet_volume': None}, {'name': 'Queen Mary', 'url': 'http://twitter.com/search?q=%22Queen+Mary%22', 'promoted_content': None, 'query': '%22Queen+Mary%22', 'tweet_volume': None}, {'name': 'Castillejo', 'url': 'http://twitter.com/search?q=Castillejo', 'promoted_content': None, 'query': 'Castillejo', 'tweet_volume': None}, {'name': 'Cerqueti', 'url': 'http://twitter.com/search?q=Cerqueti', 'promoted_content': None, 'query': 'Cerqueti', 'tweet_volume': None}, {'name': "Dall'Ara", 'url': 'http://twitter.com/search?q=Dall%27Ara', 'promoted_content': None, 'query': 'Dall%27Ara', 'tweet_volume': None}, {'name': 'Hakan', 'url': 'http://twitter.com/search?q=Hakan', 'promoted_content': None, 'query': 'Hakan', 'tweet_volume': 13408}, {'name': 'Khedira', 'url': 'http://twitter.com/search?q=Khedira', 'promoted_content': None, 'quer ...

# %% [markdown]
# ## Example 3. Displaying API responses as pretty-printed JSON

# %%
import json

print((json.dumps(us_trends[:2], indent=1)))
# Out:
# [
#  {
#   "trends": [
#    {
#     "name": "#NXTUKTakeOver",
#     "url": "http://twitter.com/search?q=%23NXTUKTakeOver",
#     "promoted_content": null,
#     "query": "%23NXTUKTakeOver",
#     "tweet_volume": 46351
#    },
#    {
#     "name": "Duke",
#     "url": "http://twitter.com/search?q=Duke",
#     "promoted_content": null,
#     "query": "Duke",
#     "tweet_volume": 36194
#    },
#    {
#     "name": "Cam Reddish",
#     "url": "http://twitter.com/search?q=%22Cam+Reddish%22",
#     "promoted_content": null,
#     "query": "%22Cam+Reddish%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Dick Vitale",
#     "url": "http://twitter.com/search?q=%22Dick+Vitale%22",
#     "promoted_content": null,
#     "query": "%22Dick+Vitale%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Chiefs",
#     "url": "http://twitter.com/search?q=Chiefs",
#     "promoted_content": null,
#     "query": "Chiefs",
#     "tweet_volume": 85860
#    },
#    {
#     "name": "#INDvsKC",
#     "url": "http://twitter.com/search?q=%23INDvsKC",
#     "promoted_content": null,
#     "query": "%23INDvsKC",
#     "tweet_volume": 18855
#    },
#    {
#     "name": "Julian Castro",
#     "url": "http://twitter.com/search?q=%22Julian+Castro%22",
#     "promoted_content": null,
#     "query": "%22Julian+Castro%22",
#     "tweet_volume": 28435
#    },
#    {
#     "name": "#UKWomensTitle",
#     "url": "http://twitter.com/search?q=%23UKWomensTitle",
#     "promoted_content": null,
#     "query": "%23UKWomensTitle",
#     "tweet_volume": null
#    },
#    {
#     "name": "RJ Barrett",
#     "url": "http://twitter.com/search?q=%22RJ+Barrett%22",
#     "promoted_content": null,
#     "query": "%22RJ+Barrett%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Toni Storm",
#     "url": "http://twitter.com/search?q=%22Toni+Storm%22",
#     "promoted_content": null,
#     "query": "%22Toni+Storm%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Rae Sremmurd",
#     "url": "http://twitter.com/search?q=%22Rae+Sremmurd%22",
#     "promoted_content": null,
#     "query": "%22Rae+Sremmurd%22",
#     "tweet_volume": 14443
#    },
#    {
#     "name": "Florida State",
#     "url": "http://twitter.com/search?q=%22Florida+State%22",
#     "promoted_content": null,
#     "query": "%22Florida+State%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "#Its2019andWeStillCant",
#     "url": "http://twitter.com/search?q=%23Its2019andWeStillCant",
#     "promoted_content": null,
#     "query": "%23Its2019andWeStillCant",
#     "tweet_volume": 15526
#    },
#    {
#     "name": "#NXTTakeOverBlackpool",
#     "url": "http://twitter.com/search?q=%23NXTTakeOverBlackpool",
#     "promoted_content": null,
#     "query": "%23NXTTakeOverBlackpool",
#     "tweet_volume": null
#    },
#    {
#     "name": "Dickie V",
#     "url": "http://twitter.com/search?q=%22Dickie+V%22",
#     "promoted_content": null,
#     "query": "%22Dickie+V%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Hotty Toddy",
#     "url": "http://twitter.com/search?q=%22Hotty+Toddy%22",
#     "promoted_content": null,
#     "query": "%22Hotty+Toddy%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Kermit Davis",
#     "url": "http://twitter.com/search?q=%22Kermit+Davis%22",
#     "promoted_content": null,
#     "query": "%22Kermit+Davis%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Finn Balor",
#     "url": "http://twitter.com/search?q=%22Finn+Balor%22",
#     "promoted_content": null,
#     "query": "%22Finn+Balor%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Tyler Bate",
#     "url": "http://twitter.com/search?q=%22Tyler+Bate%22",
#     "promoted_content": null,
#     "query": "%22Tyler+Bate%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Arrowhead",
#     "url": "http://twitter.com/search?q=Arrowhead",
#     "promoted_content": null,
#     "query": "Arrowhead",
#     "tweet_volume": 13275
#    },
#    {
#     "name": "Willian",
#     "url": "http://twitter.com/search?q=Willian",
#     "promoted_content": null,
#     "query": "Willian",
#     "tweet_volume": 42733
#    },
#    {
#     "name": "Tre Jones",
#     "url": "http://twitter.com/search?q=%22Tre+Jones%22",
#     "promoted_content": null,
#     "query": "%22Tre+Jones%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Rhea Ripley",
#     "url": "http://twitter.com/search?q=%22Rhea+Ripley%22",
#     "promoted_content": null,
#     "query": "%22Rhea+Ripley%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Pete Dunne",
#     "url": "http://twitter.com/search?q=%22Pete+Dunne%22",
#     "promoted_content": null,
#     "query": "%22Pete+Dunne%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Malik Hooker",
#     "url": "http://twitter.com/search?q=%22Malik+Hooker%22",
#     "promoted_content": null,
#     "query": "%22Malik+Hooker%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Eddie Dennis",
#     "url": "http://twitter.com/search?q=%22Eddie+Dennis%22",
#     "promoted_content": null,
#     "query": "%22Eddie+Dennis%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "NXT UK",
#     "url": "http://twitter.com/search?q=%22NXT+UK%22",
#     "promoted_content": null,
#     "query": "%22NXT+UK%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Devlin",
#     "url": "http://twitter.com/search?q=Devlin",
#     "promoted_content": null,
#     "query": "Devlin",
#     "tweet_volume": null
#    },
#    {
#     "name": "Phil Cofer",
#     "url": "http://twitter.com/search?q=%22Phil+Cofer%22",
#     "promoted_content": null,
#     "query": "%22Phil+Cofer%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Mac McClung",
#     "url": "http://twitter.com/search?q=%22Mac+McClung%22",
#     "promoted_content": null,
#     "query": "%22Mac+McClung%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Dave Mastiff",
#     "url": "http://twitter.com/search?q=%22Dave+Mastiff%22",
#     "promoted_content": null,
#     "query": "%22Dave+Mastiff%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Mustache Mountain",
#     "url": "http://twitter.com/search?q=%22Mustache+Mountain%22",
#     "promoted_content": null,
#     "query": "%22Mustache+Mountain%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Roy Williams",
#     "url": "http://twitter.com/search?q=%22Roy+Williams%22",
#     "promoted_content": null,
#     "query": "%22Roy+Williams%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Barclays",
#     "url": "http://twitter.com/search?q=Barclays",
#     "promoted_content": null,
#     "query": "Barclays",
#     "tweet_volume": null
#    },
#    {
#     "name": "Toni Time",
#     "url": "http://twitter.com/search?q=%22Toni+Time%22",
#     "promoted_content": null,
#     "query": "%22Toni+Time%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "#NXTUKTagTitles",
#     "url": "http://twitter.com/search?q=%23NXTUKTagTitles",
#     "promoted_content": null,
#     "query": "%23NXTUKTagTitles",
#     "tweet_volume": null
#    },
#    {
#     "name": "#snowpocalypse2019",
#     "url": "http://twitter.com/search?q=%23snowpocalypse2019",
#     "promoted_content": null,
#     "query": "%23snowpocalypse2019",
#     "tweet_volume": null
#    },
#    {
#     "name": "#TakeAFilmBackToTheFuture",
#     "url": "http://twitter.com/search?q=%23TakeAFilmBackToTheFuture",
#     "promoted_content": null,
#     "query": "%23TakeAFilmBackToTheFuture",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ToniTime",
#     "url": "http://twitter.com/search?q=%23ToniTime",
#     "promoted_content": null,
#     "query": "%23ToniTime",
#     "tweet_volume": null
#    },
#    {
#     "name": "#Caturday",
#     "url": "http://twitter.com/search?q=%23Caturday",
#     "promoted_content": null,
#     "query": "%23Caturday",
#     "tweet_volume": 20549
#    },
#    {
#     "name": "#Julian2020",
#     "url": "http://twitter.com/search?q=%23Julian2020",
#     "promoted_content": null,
#     "query": "%23Julian2020",
#     "tweet_volume": null
#    },
#    {
#     "name": "#RussianAsset",
#     "url": "http://twitter.com/search?q=%23RussianAsset",
#     "promoted_content": null,
#     "query": "%23RussianAsset",
#     "tweet_volume": 51180
#    },
#    {
#     "name": "#SaturdayMorning",
#     "url": "http://twitter.com/search?q=%23SaturdayMorning",
#     "promoted_content": null,
#     "query": "%23SaturdayMorning",
#     "tweet_volume": 47090
#    },
#    {
#     "name": "#CHENEW",
#     "url": "http://twitter.com/search?q=%23CHENEW",
#     "promoted_content": null,
#     "query": "%23CHENEW",
#     "tweet_volume": 32996
#    },
#    {
#     "name": "#BabyOneMoreTime20",
#     "url": "http://twitter.com/search?q=%23BabyOneMoreTime20",
#     "promoted_content": null,
#     "query": "%23BabyOneMoreTime20",
#     "tweet_volume": 17110
#    },
#    {
#     "name": "#snowday",
#     "url": "http://twitter.com/search?q=%23snowday",
#     "promoted_content": null,
#     "query": "%23snowday",
#     "tweet_volume": null
#    },
#    {
#     "name": "#SaturdayThoughts",
#     "url": "http://twitter.com/search?q=%23SaturdayThoughts",
#     "promoted_content": null,
#     "query": "%23SaturdayThoughts",
#     "tweet_volume": 22860
#    },
#    {
#     "name": "#PokemonGOCommunityDay",
#     "url": "http://twitter.com/search?q=%23PokemonGOCommunityDay",
#     "promoted_content": null,
#     "query": "%23PokemonGOCommunityDay",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ColtsForged",
#     "url": "http://twitter.com/search?q=%23ColtsForged",
#     "promoted_content": null,
#     "query": "%23ColtsForged",
#     "tweet_volume": null
#    },
#    {
#     "name": "#MyRealLifeLawAndOrder",
#     "url": "http://twitter.com/search?q=%23MyRealLifeLawAndOrder",
#     "promoted_content": null,
#     "query": "%23MyRealLifeLawAndOrder",
#     "tweet_volume": null
#    }
#   ],
#   "as_of": "2019-01-12T21:12:44Z",
#   "created_at": "2019-01-12T21:07:27Z",
#   "locations": [
#    {
#     "name": "United States",
#     "woeid": 23424977
#    }
#   ]
#  }
# ]

# %% [markdown]
# ## Example 4. Computing the intersection of two sets of trends

# %%
trends_set = {}
trends_set['world'] = set([trend['name'] 
                        for trend in world_trends[0]['trends']])

trends_set['us'] = set([trend['name'] 
                     for trend in us_trends[0]['trends']]) 

trends_set['san diego'] = set([trend['name'] 
                     for trend in local_trends[0]['trends']])

# %%
for loc in ['world','us','san diego']:
    print(('-'*10,loc))
    print((','.join(trends_set[loc])))
# Out:
# ('----------', 'world')
# #ChiefsKingdom,#EnBüyükBelaSevgisizlik,Cam Reddish,#Bets10PokerFreerollBinTL,#ukwomenstitle,#CoppaItalia,#JinGaveMeWings,#السعوديه_لبنان,#INDvsKC,David Luiz,Toni Storm,Cutrone,#نتايج_الثانويه_العامه,#HalkEytDiyor,Willian,#LetsRoll,#widm,#ÇekeVarsaTümBorçlaraHapis,Rae Sremmurd,#صندوق_السبع_Momax,#Its2019andWeStillCant,#ToniTime,Julian Castro,Bilal,#TeslaTRTBelgeselde,#SamsunOrjinCafedeSu8TL,Dick Vitale,#1YearOfCamila,#DestinationEurovision,#EstoyConGuaido,Finn Balor,Duke,#بالوقت_هذا_احتاج,#SampdoriaMilan,#cepostaperte,Pete Dunne,#NXTUKTagTitles,RJ Barrett,Florida State,#BabyOneMoreTime20,#40BinÖğrtAtamasıHaktır,#NXTTakeOverBlackpool,#BolognaJuve,Newcastle,#L6Nacuerdos,#OGCNFCGB,#NXTUKTakeOver,Chimène Badi,#CHENEW,#moltalk
# ('----------', 'us')
# #PokemonGOCommunityDay,Eddie Dennis,Roy Williams,#Julian2020,Cam Reddish,NXT UK,Chiefs,#SaturdayMorning,Dickie V,Tyler Bate,#INDvsKC,Toni Storm,Phil Cofer,Toni Time,#RussianAsset,#snowpocalypse2019,Willian,Dave Mastiff,#snowday,#MyRealLifeLawAndOrder,Malik Hooker,Rae Sremmurd,#Its2019andWeStillCant,#ToniTime,Julian Castro,Arrowhead,#Caturday,#ColtsForged,Dick Vitale,Kermit Davis,Finn Balor,Duke,Tre Jones,Pete Dunne,#NXTUKTagTitles,RJ Barrett,Florida State,#TakeAFilmBackToTheFuture,#BabyOneMoreTime20,Hotty Toddy,#NXTTakeOverBlackpool,Mac McClung,Devlin,Rhea Ripley,Barclays,#NXTUKTakeOver,#SaturdayThoughts,#CHENEW,Mustache Mountain,#UKWomensTitle
# ('----------', 'san diego')
# Dall'Ara,#NewTrolls,Ricky Martin,Olga Fernando,Reina,Spinazzola,saponara,#CoppaItalia,#Kean,#Obiang,Seungri,Castillejo,#RaiSport,Queen Mary,#perugiacivitanova,#SampMilan,Da Costa,#Gattuso,#ForzaMilan,#Paqueta,#BrendonPortaIlTuoCuloInItalia,De Sciglio,Andrea Cerioli,#Cutrone,#SferaEbbasta,Borini,Paquetà,Patrick,Hakan,#Rafael,#TIMCup,Alexandra,Abate,Khedira,#PrincipeLibero,#SampdoriaMilan,Higuain,Conti,#cepostaperte,Quagliarella,Maria,La Samp,Douglas Costa,#Toscani,Chiellini,#BolognaJuve,#jvtblive,Cerqueti,Calhanoglu,#FinoAllaFine

# %%
print(( '='*10,'intersection of world and us'))
print((trends_set['world'].intersection(trends_set['us'])))

print(('='*10,'intersection of us and san-diego'))
print((trends_set['san diego'].intersection(trends_set['us'])))
# Out:
# ('==========', 'intersection of world and us')
# {'Pete Dunne', '#NXTUKTagTitles', 'Willian', 'RJ Barrett', 'Florida State', 'Cam Reddish', '#BabyOneMoreTime20', '#NXTTakeOverBlackpool', 'Rae Sremmurd', 'Dick Vitale', '#Its2019andWeStillCant', '#NXTUKTakeOver', 'Finn Balor', '#CHENEW', '#INDvsKC', '#ToniTime', 'Toni Storm', 'Julian Castro', 'Duke'}
# ('==========', 'intersection of us and san-diego')
# set()

# %% [markdown]
# ## Example 5. Collecting search results

# %%
q = '#MTVAwards' 

number = 100

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

search_results = twitter_api.search.tweets(q=q, count=number)

statuses = search_results['statuses']

# %%
len(statuses)
print(statuses)
# Out:
# [{'created_at': 'Sat Jan 12 16:33:52 +0000 2019', 'id': 1084126323327549440, 'id_str': '1084126323327549440', 'text': 'RT @MTV: Look!!! At!!! These!!! Cuties!!! #MTVAwards https://t.co/y8lBEgD8V7', 'truncated': False, 'entities': {'hashtags': [{'text': 'MTVAwards', 'indices': [42, 52]}], 'symbols': [], 'user_mentions': [{'screen_name': 'MTV', 'name': 'MTV', 'id': 2367911, 'id_str': '2367911', 'indices': [3, 7]}], 'urls': [], 'media': [{'id': 1008896054736052224, 'id_str': '1008896054736052224', 'indices': [53, 76], 'media_url': 'http://pbs.twimg.com/media/DgBRnc3V4AAPkpU.jpg', 'media_url_https': 'https://pbs.twimg.com/media/DgBRnc3V4AAPkpU.jpg', 'url': 'https://t.co/y8lBEgD8V7', 'display_url': 'pic.twitter.com/y8lBEgD8V7', 'expanded_url': 'https://twitter.com/MTV/status/1008896124260716544/photo/1', 'type': 'photo', 'sizes': {'small': {'w': 680, 'h': 536, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 2048, 'h': 1613, 'resize': 'fit'}, 'medium': {'w': 1200, 'h': 945, 'resize': 'fit'}}, 'source_status_id': 1008896124260716544, 'source_status_id_str': '1008896124260716544', 'source_user_id': 2367911, 'source_user_id_str': '2367911'}]}, 'extended_entities': {'media': [{'id': 1008896054736052224, 'id_str': '1008896054736052224', 'indices': [53, 76], 'media_url': 'http://pbs.twimg.com/media/DgBRnc3V4AAPkpU.jpg', 'media_url_https': 'https://pbs.twimg.com/media/DgBRnc3V4AAPkpU.jpg', 'url': 'https://t.co/y8lBEgD8V7', 'display_url': 'pic.twitter.com/y8lBEgD8V7', 'expanded_url': 'https://twitter.com/MTV/status/1008896124260716544/photo/1', 'type': 'photo', 'sizes': {'small': {'w': 680, 'h': 536, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 2048, 'h': 1613, 'resize': 'fit'}, 'medium': {'w': 1200, 'h': 945, 'resize': 'fit'}}, 'source_status_id': 1008896124260716544, 'source_status_id_str': '1008896124260716544', 'source_user_id': 2367911, 'source_user_id_str': '2367911'}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1076370137941528576, 'id_str': '1076370137941528576', 'name': 'rd👀', 'screen_name': 'heybenimrd', 'location': '', 'description': '🌊✨', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 58, 'friends_count': 238, 'listed_count': 0, 'created_at': 'Sat Dec 22 06:53:33 +0000 2018', 'favourites_count': 796, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 171, 'lang': 'tr', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1082377893349654528/p-NRPKe-_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1082377893349654528/p-NRPKe-_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1076370137941528576/1546886348', 'profile_link_color': '000000', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Tue Jun 19 02:15:55 +0000 2018', 'id': 1008896124260716544, 'id_str': '1008896124260716544', 'text': 'Look!!! At!!! These!!! Cut ...

# %%
all_text = []
filtered_statuses = []
for s in statuses:
    if not s["text"] in all_text:
        filtered_statuses.append(s)
        all_text.append(s["text"])
statuses = filtered_statuses

# %%
len(statuses)
# Out:
# 65

# %%
[s['text'] for s in search_results['statuses']]
# Out:
# ['RT @MTV: Look!!! At!!! These!!! Cuties!!! #MTVAwards https://t.co/y8lBEgD8V7',
#  'RT @MTV: My bb Katherine Langford just wanted to say hi from backstage at the #MTVAwards 💕 https://t.co/FnEqEGEClX',
#  'Who is #RIGHTJUSTxREBEL ??? @rightjustgcoded  x @rebelpoc  \n🌐God•Goals•Grind🌐\nSubscribe/like/share/donate\nLink in b… https://t.co/i3l2EDWUS0',
#  'RT @glossdaya: chloe and halle are angels beyoncé really did bless them #mtvawards  https://t.co/y2fDHMj3rs',
#  'RT @PeytonList: Post rain #MTVAwards https://t.co/UnoizJRx8D',
#  '#Andre3000 @1future \n🏃 |Culture Guardians |  link in bio \nSubscribe/like/share/\n #applemusic #spotify #tidal… https://t.co/KSWUfuly78',
#  'RT @jaedenlieberher: Catch us on the #MTVAwards tonight! https://t.co/5mBLkKT11x',
#  '🏃 |Culture Guardians |  link in bio \nSubscribe/like/share/\n #applemusic #spotify #tidal  #complex #xxlfreshmen… https://t.co/peZRYaOQuo',
#  'RT @EmmaWatson: Thank you @MTV for a wonderful evening and thank you to everyone who voted for me! ❤️🍿 #MTVAwards @beourguest',
#  'Han vendido mas de 40 millones de 💿. Han ganado #grammy #mtvawards &amp; #britawards \nHoy a las 🕙10:00 pm en @locafm 2h… https://t.co/WwQUBP4G6z',
#  'They’ve sold more than 40 million of 💿. Winners of many #grammy #mtvawards  #britawards \nTonight 🕙10:00 pm at… https://t.co/GjIP8qOCw5',
#  'RT @MTV: Losers Club lookin’ reallllll dapper at the #MTVAwards ✨ Catch the @ITMovieOfficial cast tonight at 9/8c! | 🎥: Justin NB Francis h…',
#  'RT @CMBYNFilm: Congratulations to @RealChalamet on his \n@MTVAwards nomination for Best Performance in a Movie. Vote today: https://t.co/SVb…',
#  'Da Takeover @NubiaSoulGODdes #soul \n#fashion #style #swagg #showkiller #hiphop #hottestinatlanta #atlshottest… https://t.co/e3RUW2y0jb',
#  '#Repost imindieradio\n• • • • •\nDa Takeover @NubiaSoulGODdes #soul \n#fashion #style #swagg #showkiller #hiphop… https://t.co/uqZCvjXonZ',
#  '#Repost IM Indie radio\n• • • • •\nDa Takeover Nubia Soul GODdess #soul \n#fashion #style #swagg #showkiller #hiphop… https://t.co/Y7vLgy0yPT',
#  "RT @tylergposey: last year I wore a onesie, this year who knows? tomorrow's the #mtvawards and I'm teaming up w/#ToyotaCHR to make some mis…",
#  'RT @CMBYNFilm: Congratulations to @RealChalamet on his \n@MTVAwards nomination for Best Performance in a Movie. Vote today: https://t.co/SVb…',
#  'Same. But for #MTVawards #FickleSeries https://t.co/CINRiiyieU',
#  'RT @etnow: Congrats to Best Kiss winners @AshDSanders and @JharrelJerome! #MTVAwards 😘 https://t.co/BiAsKQvEUF',
#  'RT @MTV: Look!!! At!!! These!!! Cuties!!! #MTVAwards https://t.co/y8lBEgD8V7',
#  'RT @SpiritRider1: Chris Pratt receiving #generationAward speech - 9 points \n #MTVAwards https://t.co/NFbCpopRIO',
#  'The trend is your friend? https://t.co/jhkSroCt6O tv, movie, excited, wow, omg, mtv, damn, tv land, tvland, adam, a… https://t.co/oQtQWsXWLR',
#  'New trending GIF tagged tv, movie, excited, wow, omg, mtv, damn, tv land, tvland, adam, awards, adam devine, holy s… https://t.co/h2P21nfZAM',
#  'RT @MTV: My queens @chloexhalle slayed their performance at the #MTVAwards 😍 https://t.co/cDZ8kwmkF9',
#  'RT @PeytonList: Post rain #MTVAwards https://t.co/UnoizJRx8D',
#  'RT @Variety: #StrangerThings @noah_schnapp wants to meet @Zendaya: "I love her" #MTVAwards https://t.co/WUK5j3LLqV https://t.co/SK2bIPNmWQ',
#  'RT @MTV: My queens @chloexhalle slayed their performance at the #MTVAwards 😍 https://t.co/cDZ8kwmkF9',
#  'RT @MTV: My queens @chloexhalle slayed their performance at the #MTVAwards 😍 https://t.co/cDZ8kwmkF9',
#  'RT @MTV: My queens @chloexhalle slayed their performance at the #MTVAwards 😍 https://t.co/cDZ8kwmkF9',
#  'RT @MTV: Thank you for your beautiful Best Actor in a Movie acceptance speech at the #MTVAwards, @EmmaWatson 💖 https://t.co/iGN3nQQylL',
#  'RT @MTV: 1 of 9 rules from @prattprattpratt "Don\'t be a 💩" Congrats on receiving the Generation Award! #MTVAwards https://t.co/IFn87o8Kuk',
#  '🏃 |Culture Guardians |  link in bio \nSubscribe/like/share/\n #applemusic #spotify #tidal  #complex #xxlfreshmen… https://t.co/gCUblj0NP2',
#  'flippdinero \n🏃 |Culture Guardians |  link in bio \nSubscribe/like/share/\n #applemusic #spotify #tidal  #complex… https://t.co/NyRgCRqdV5',
#  'RT @MTV: 1 of 9 rules from @prattprattpratt "Don\'t be a 💩" Congrats on receiving the Generation Award! #MTVAwards https://t.co/IFn87o8Kuk',
#  'RT @MTVAwards: Your fave @lindsaylohan won a Golden Popcorn at the 2004 #MTVAwards for the classic "Freaky Friday." 🍿\n\nShe\'s back on @MTV T…',
#  '#Repost @katgraham ・・・\n@instyle’s BYOB (boombox) Party 🍾💥 #InStyleWBGlobes\n....\n#katgraham #instylewbglobes… https://t.co/1xJTxvWd21',
#  'RT @MTV: My queens @chloexhalle slayed their performance at the #MTVAwards 😍 https://t.co/cDZ8kwmkF9',
#  'RT @MTV: I hope the cast of #13ReasonsWhy knows how much I love them!!!!!!! | Catch them at the #MTVAwards on Monday at 9/8c! 💞 https://t.c…',
#  'Track @TwitterMovies #movies #film #moviestars #mtvawards #AcademyAwards w #HashNewsGram https://t.co/kxd81D1I31 … https://t.co/vhDNxHh15J',
#  'RT @MTVAwards: Your fave @lindsaylohan won a Golden Popcorn at the 2004 #MTVAwards for the classic "Freaky Friday." 🍿\n\nShe\'s back on @MTV T…',
#  'RT @glossdaya: chloe and halle are angels beyoncé really did bless them #mtvawards  https://t.co/y2fDHMj3rs',
#  'Your fave @lindsaylohan won a Golden Popcorn at the 2004 #MTVAwards for the classic "Freaky Friday." 🍿\n\nShe\'s back… https://t.co/vXMVCL3XBU',
#  'RT @getFANDOM: Chris Pratt with all of the wisdom #MTVAwards https://t.co/eu5cXU7WcQ',
#  'RT @getFANDOM: Chris Pratt with all of the wisdom #MTVAwards https://t.co/eu5cXU7WcQ',
#  'RT @MTV: My queens @chloexhalle slayed their performance at the #MTVAwards 😍 https://t.co/cDZ8kwmkF9',
#  'RT @MTV: My queens @chloexhalle slayed their performance at the #MTVAwards 😍 https://t.co/cDZ8kwmkF9',
#  'RT @MTV: We love a pair of #MTVAwards besties 💘 @TommyDorfman @madelainepetsch https://t.co/EcTVGCLf78',
#  'RT @iamctrex: "Why" - @nfrealmusic 🌿\n➡️ Don\'t forget to SHARE MY POST for more covers like this.\n❌ FOLLOW ME ON THE SOCIAL MEDIA ❌\n.\n.\n.\n.…',
#  '"Why" - @nfrealmusic 🌿\n➡️ Don\'t forget to SHARE MY POST for more covers like this.\n❌ FOLLOW ME ON THE SOCIAL MEDIA… https://t.co/beGUeObmxW',
#  'RT @ChoniBrasil: Vanessa e Madelaine conversando (via @OhMySanchez)\n#MTVAwards https://t.co/hi2Bv2abB9',
#  'RT @VMorganBR: Vanessa e Madelaine no tapete vermelho do MTV Movie &amp; TV Awards #MTVAwards\u2060 \u2060\u2060 \u2060\u2060 \u2060 https://t.co/sG67O4VEXJ',
#  "RT @empathgirl: Chris Pratt is talking about praying and God.\n\nHe's definitely All Lives Matter.\n\nI don't trust white Christians.\n\n#MTVAwar…",
#  'RT @chloexhalle: who caught our performance last night at the #mtvawards?! we had so much fun!! 👯 relive the moment with us and let us know…',
#  "RT @MTV: The Losers' Club? More like the WINNERS CLUB ☺️☺️The cast of #ITMovie wins Best On-Screen Team at the #MTVAwards https://t.co/lq5u…",
#  'RT @MTVAwards: OH HEYY LITTLE MONSTERS 👋👋👋\nThe QUEEN @LadyGaga won Best Music Documentary for ‘Gaga: Five Foot Two.’ | Tune into #MTVAwards…',
#  'RT @ladygaga: So happy that #GagaFiveFootTwo won Best Music Documentary at the #MTVAwards! Thank u Little Monsters &amp; @MTV!! 😘 https://t.co/…',
#  'RT @weeklygaga: Have you voted today #LittleMonsters Remember you can vote daily for #ladygaga‘s “Gaga: Five Foot Two” for “Best Music Docu…',
#  "RT @MTV: @ladygaga congrats!!! you've been nominated at the 2018 #mtvawards and can vote now at https://t.co/B6c16HKCG5 🌈 https://t.co/HQec…",
#  'RT @MTV: My queens @chloexhalle slayed their performance at the #MTVAwards 😍 https://t.co/cDZ8kwmkF9',
#  '@TeniEntertainer A great influence , motivator,  good to say I found a new mentor.. ♥ #nextrated mama T ♥ 👑...  Con… https://t.co/GEOpujr15s',
#  'RT @MTV: My queens @chloexhalle slayed their performance at the #MTVAwards 😍 https://t.co/cDZ8kwmkF9',
#  'RT @iamctrex: "Like That" - @beamiller 🌻\n➡️ Don\'t forget to SHARE MY POST for more covers like this.\n❌ FOLLOW ME ON THE SOCIAL MEDIA ❌\n.\n.…',
#  '"Like That" - @beamiller 🌻\n➡️ Don\'t forget to SHARE MY POST for more covers like this.\n❌ FOLLOW ME ON THE SOCIAL ME… https://t.co/MxlQetkqG0',
#  'ガンズにエルトン・ジョン\nもう無いな\nこんなセッション\nアクセルの対面にエルトン・ジョン\n一緒にピアノ弾く\nスラッシュ\nピアノの上に乗って\nレスポール鳴らす\n興奮しかないな\nこんな光景\n#gunsnroses… https://t.co/7pCrZjbuOm',
#  'RT @ZendayaMedia: Zendaya and Tom Holland present an exclusive #SpiderManHomecoming clip at the #MTVAwards https://t.co/TBlWIApeIf',
#  '@ym_lilquez "misunderstood" project\n🌐God•Goals•Grind🌐\nSubscribe/like/share/\nLink in bio\n #applemusic #spotify… https://t.co/ynHoZnzG4v',
#  'RT @MTV: My queens @chloexhalle slayed their performance at the #MTVAwards 😍 https://t.co/cDZ8kwmkF9',
#  'RT @zane: Didn’t get invited to the #MTVAwards so we snuck in. Make sure to watch it tonight @ 9/8c only on @MTV👾 https://t.co/FYwVLdHw8y',
#  'RT @cxhupdates: Chloe and Halle performing at the #MTVAwards https://t.co/cZHo1RiYxU',
#  'RT @ladygaga: So happy that #GagaFiveFootTwo won Best Music Documentary at the #MTVAwards! Thank u Little Monsters &amp; @MTV!! 😘 https://t.co/…',
#  "RT @MTV: A tutorial in how to be charming af ft. @13ReasonsWhy's @JustinPrentice and @TGranaderos🕺 Get even more of these two at the #MTVAw…",
#  'RT @DuecyMargielaa: #FirstTakeBoyz 🔥🔥🔥#FirstTakeBoyz 🔥🔥🔥#FirstTakeBoyz 🔥🔥🔥#FirstTakeBoyz 🔥🔥🔥#FirstTakeBoyz 🔥🔥🔥 #mtvawards #ambitiousrecords…',
#  '@emastokholma\nIn mtvitalia #mtvawards #firenze\n#dj #famous #producer #woman #music #emastokholma #djset #event… https://t.co/xvVSOKlaRC',
#  'RT @Benji_Mascolo: Ho detto tutto. #MTVAwards https://t.co/csyoraPWuc',
#  'RT @KeiynanLonsdale: #MTVAwards ✨👁❤️ https://t.co/nY44VpYgjy',
#  'RT @MTV: Losers Club lookin’ reallllll dapper at the #MTVAwards ✨ Catch the @ITMovieOfficial cast tonight at 9/8c! | 🎥: Justin NB Francis h…',
#  'RT @MTV: Let @dylanobrien guide you through a first look at Maze Runner: The Death Cure, exclusively for the #MTVAwards tonight at 8/7c! 💥…',
#  'RT @MTVAwards: Still have goosebumps from this heavenly @ChloexHalle performance tbh #MTVAwards https://t.co/Ie8gv5m4So',
#  '@Modenine is the 💣💣💣\nA  N  T  I  C  I  P  A  T  E\nThe MONUMENT 💯\n#betintlactafrica #mtvbaseafrica #mtvawards… https://t.co/ebnIknDLH3',
#  'RT @VanessaMorgan: . @iammurray and I teamed up with @simplemobile to give YOU a behind the scenes look into the #MTVAwards https://t.co/aa…',
#  'RT @forever_kolored: Telefono in mano che ci sarà da votare la performance su Twitter #MTVAwards #SofiaViscardi \n.\n#VotaTheKolorsMTV https:…',
#  'RT @federicodevito: Eu tô GRITANDO com as donas da Netflix, KATHERINE LANGFORD E MILLIE BOBBY BROWN, JUNTAS  #MTVAwards https://t.co/6C3H3G…']

# %%
# Show one sample search result by slicing the list...
print(json.dumps(statuses[0], indent=1))
# Out:
# {
#  "created_at": "Sat Jan 12 16:33:52 +0000 2019",
#  "id": 1084126323327549440,
#  "id_str": "1084126323327549440",
#  "text": "RT @MTV: Look!!! At!!! These!!! Cuties!!! #MTVAwards https://t.co/y8lBEgD8V7",
#  "truncated": false,
#  "entities": {
#   "hashtags": [
#    {
#     "text": "MTVAwards",
#     "indices": [
#      42,
#      52
#     ]
#    }
#   ],
#   "symbols": [],
#   "user_mentions": [
#    {
#     "screen_name": "MTV",
#     "name": "MTV",
#     "id": 2367911,
#     "id_str": "2367911",
#     "indices": [
#      3,
#      7
#     ]
#    }
#   ],
#   "urls": [],
#   "media": [
#    {
#     "id": 1008896054736052224,
#     "id_str": "1008896054736052224",
#     "indices": [
#      53,
#      76
#     ],
#     "media_url": "http://pbs.twimg.com/media/DgBRnc3V4AAPkpU.jpg",
#     "media_url_https": "https://pbs.twimg.com/media/DgBRnc3V4AAPkpU.jpg",
#     "url": "https://t.co/y8lBEgD8V7",
#     "display_url": "pic.twitter.com/y8lBEgD8V7",
#     "expanded_url": "https://twitter.com/MTV/status/1008896124260716544/photo/1",
#     "type": "photo",
#     "sizes": {
#      "small": {
#       "w": 680,
#       "h": 536,
#       "resize": "fit"
#      },
#      "thumb": {
#       "w": 150,
#       "h": 150,
#       "resize": "crop"
#      },
#      "large": {
#       "w": 2048,
#       "h": 1613,
#       "resize": "fit"
#      },
#      "medium": {
#       "w": 1200,
#       "h": 945,
#       "resize": "fit"
#      }
#     },
#     "source_status_id": 1008896124260716544,
#     "source_status_id_str": "1008896124260716544",
#     "source_user_id": 2367911,
#     "source_user_id_str": "2367911"
#    }
#   ]
#  },
#  "extended_entities": {
#   "media": [
#    {
#     "id": 1008896054736052224,
#     "id_str": "1008896054736052224",
#     "indices": [
#      53,
#      76
#     ],
#     "media_url": "http://pbs.twimg.com/media/DgBRnc3V4AAPkpU.jpg",
#     "media_url_https": "https://pbs.twimg.com/media/DgBRnc3V4AAPkpU.jpg",
#     "url": "https://t.co/y8lBEgD8V7",
#     "display_url": "pic.twitter.com/y8lBEgD8V7",
#     "expanded_url": "https://twitter.com/MTV/status/1008896124260716544/photo/1",
#     "type": "photo",
#     "sizes": {
#      "small": {
#       "w": 680,
#       "h": 536,
#       "resize": "fit"
#      },
#      "thumb": {
#       "w": 150,
#       "h": 150,
#       "resize": "crop"
#      },
#      "large": {
#       "w": 2048,
#       "h": 1613,
#       "resize": "fit"
#      },
#      "medium": {
#       "w": 1200,
#       "h": 945,
#       "resize": "fit"
#      }
#     },
#     "source_status_id": 1008896124260716544,
#     "source_status_id_str": "1008896124260716544",
#     "source_user_id": 2367911,
#     "source_user_id_str": "2367911"
#    }
#   ]
#  },
#  "metadata": {
#   "iso_language_code": "en",
#   "result_type": "recent"
#  },
#  "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#  "in_reply_to_status_id": null,
#  "in_reply_to_status_id_str": null,
#  "in_reply_to_user_id": null,
#  "in_reply_to_user_id_str": null,
#  "in_reply_to_screen_name": null,
#  "user": {
#   "id": 1076370137941528576,
#   "id_str": "1076370137941528576",
#   "name": "rd\ud83d\udc40",
#   "screen_name": "heybenimrd",
#   "location": "",
#   "description": "\ud83c\udf0a\u2728",
#   "url": null,
#   "entities": {
#    "description": {
#     "urls": []
#    }
#   },
#   "protected": false,
#   "followers_count": 58,
#   "friends_count": 238,
#   "listed_count": 0,
#   "created_at": "Sat Dec 22 06:53:33 +0000 2018",
#   "favourites_count": 796,
#   "utc_offset": null,
#   "time_zone": null,
#   "geo_enabled": false,
#   "verified": false,
#   "statuses_count": 171,
#   "lang": "tr",
#   "contributors_enabled": false,
#   "is_translator": false,
#   "is_translation_enabled": false,
#   "profile_background_color": "000000",
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#   "profile_background_tile": false,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/1082377893349654528/p-NRPKe-_normal.jpg",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/1082377893349654528/p-NRPKe-_normal.jpg",
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/1076370137941528576/1546886348",
#   "profile_link_color": "000000",
#   "profile_sidebar_border_color": "000000",
#   "profile_sidebar_fill_color": "000000",
#   "profile_text_color": "000000",
#   "profile_use_background_image": false,
#   "has_extended_profile": true,
#   "default_profile": false,
#   "default_profile_image": false,
#   "following": false,
#   "follow_request_sent": false,
#   "notifications": false,
#   "translator_type": "none"
#  },
#  "geo": null,
#  "coordinates": null,
#  "place": null,
#  "contributors": null,
#  "retweeted_status": {
#   "created_at": "Tue Jun 19 02:15:55 +0000 2018",
#   "id": 1008896124260716544,
#   "id_str": "1008896124260716544",
#   "text": "Look!!! At!!! These!!! Cuties!!! #MTVAwards https://t.co/y8lBEgD8V7",
#   "truncated": false,
#   "entities": {
#    "hashtags": [
#     {
#      "text": "MTVAwards",
#      "indices": [
#       33,
#       43
#      ]
#     }
#    ],
#    "symbols": [],
#    "user_mentions": [],
#    "urls": [],
#    "media": [
#     {
#      "id": 1008896054736052224,
#      "id_str": "1008896054736052224",
#      "indices": [
#       44,
#       67
#      ],
#      "media_url": "http://pbs.twimg.com/media/DgBRnc3V4AAPkpU.jpg",
#      "media_url_https": "https://pbs.twimg.com/media/DgBRnc3V4AAPkpU.jpg",
#      "url": "https://t.co/y8lBEgD8V7",
#      "display_url": "pic.twitter.com/y8lBEgD8V7",
#      "expanded_url": "https://twitter.com/MTV/status/1008896124260716544/photo/1",
#      "type": "photo",
#      "sizes": {
#       "small": {
#        "w": 680,
#        "h": 536,
#        "resize": "fit"
#       },
#       "thumb": {
#        "w": 150,
#        "h": 150,
#        "resize": "crop"
#       },
#       "large": {
#        "w": 2048,
#        "h": 1613,
#        "resize": "fit"
#       },
#       "medium": {
#        "w": 1200,
#        "h": 945,
#        "resize": "fit"
#       }
#      }
#     }
#    ]
#   },
#   "extended_entities": {
#    "media": [
#     {
#      "id": 1008896054736052224,
#      "id_str": "1008896054736052224",
#      "indices": [
#       44,
#       67
#      ],
#      "media_url": "http://pbs.twimg.com/media/DgBRnc3V4AAPkpU.jpg",
#      "media_url_https": "https://pbs.twimg.com/media/DgBRnc3V4AAPkpU.jpg",
#      "url": "https://t.co/y8lBEgD8V7",
#      "display_url": "pic.twitter.com/y8lBEgD8V7",
#      "expanded_url": "https://twitter.com/MTV/status/1008896124260716544/photo/1",
#      "type": "photo",
#      "sizes": {
#       "small": {
#        "w": 680,
#        "h": 536,
#        "resize": "fit"
#       },
#       "thumb": {
#        "w": 150,
#        "h": 150,
#        "resize": "crop"
#       },
#       "large": {
#        "w": 2048,
#        "h": 1613,
#        "resize": "fit"
#       },
#       "medium": {
#        "w": 1200,
#        "h": 945,
#        "resize": "fit"
#       }
#      }
#     }
#    ]
#   },
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   },
#   "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#    "id": 2367911,
#    "id_str": "2367911",
#    "name": "MTV",
#    "screen_name": "MTV",
#    "location": "NYC",
#    "description": "lmk if u wanna talk about harry styles",
#    "url": "https://t.co/yyniasrs2z",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "https://t.co/yyniasrs2z",
#        "expanded_url": "http://mtv.com",
#        "display_url": "mtv.com",
#        "indices": [
#         0,
#         23
#        ]
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "protected": false,
#    "followers_count": 15497716,
#    "friends_count": 31879,
#    "listed_count": 31684,
#    "created_at": "Mon Mar 26 22:30:49 +0000 2007",
#    "favourites_count": 18638,
#    "utc_offset": null,
#    "time_zone": null,
#    "geo_enabled": false,
#    "verified": true,
#    "statuses_count": 274082,
#    "lang": "en",
#    "contributors_enabled": false,
#    "is_translator": false,
#    "is_translation_enabled": true,
#    "profile_background_color": "131516",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme14/bg.gif",
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme14/bg.gif",
#    "profile_background_tile": true,
#    "profile_image_url": "http://pbs.twimg.com/profile_images/1069242871566475264/6IGCysgr_normal.jpg",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/1069242871566475264/6IGCysgr_normal.jpg",
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/2367911/1547053154",
#    "profile_link_color": "009999",
#    "profile_sidebar_border_color": "FFFFFF",
#    "profile_sidebar_fill_color": "EFEFEF",
#    "profile_text_color": "333333",
#    "profile_use_background_image": true,
#    "has_extended_profile": false,
#    "default_profile": false,
#    "default_profile_image": false,
#    "following": false,
#    "follow_request_sent": false,
#    "notifications": false,
#    "translator_type": "regular"
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "is_quote_status": false,
#   "retweet_count": 1863,
#   "favorite_count": 9798,
#   "favorited": false,
#   "retweeted": false,
#   "possibly_sensitive": false,
#   "lang": "en"
#  },
#  "is_quote_status": false,
#  "retweet_count": 1863,
#  "favorite_count": 0,
#  "favorited": false,
#  "retweeted": false,
#  "possibly_sensitive": false,
#  "lang": "en"
# }

# %%
# The result of the list comprehension is a list with only one element that
# can be accessed by its index and set to the variable t
t = statuses[0]
#[ status for status in statuses 
#          if status['id'] == 316948241264549888 ][0]

# Explore the variable t to get familiarized with the data structure...

print(t['retweet_count'])
print(t['retweeted'])
# Out:
# 1863
# False

# %% [markdown]
# ## Example 6. Extracting text, screen names, and hashtags from tweets

# %%
status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# Compute a collection of all words from all tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# %%
# Explore the first 5 items for each...

print(json.dumps(status_texts[0:5], indent=1))
print(json.dumps(screen_names[0:5], indent=1)) 
print(json.dumps(hashtags[0:5], indent=1))
print(json.dumps(words[0:5], indent=1))
# Out:
# [
#  "RT @MTV: Look!!! At!!! These!!! Cuties!!! #MTVAwards https://t.co/y8lBEgD8V7",
#  "RT @MTV: My bb Katherine Langford just wanted to say hi from backstage at the #MTVAwards \ud83d\udc95 https://t.co/FnEqEGEClX",
#  "Who is #RIGHTJUSTxREBEL ??? @rightjustgcoded  x @rebelpoc  \n\ud83c\udf10God\u2022Goals\u2022Grind\ud83c\udf10\nSubscribe/like/share/donate\nLink in b\u2026 https://t.co/i3l2EDWUS0",
#  "RT @glossdaya: chloe and halle are angels beyonc\u00e9 really did bless them #mtvawards  https://t.co/y2fDHMj3rs",
#  "RT @PeytonList: Post rain #MTVAwards https://t.co/UnoizJRx8D"
# ]
# [
#  "MTV",
#  "MTV",
#  "RIGHTJUSTGcoded",
#  "REBELPOC",
#  "glossdaya"
# ]
# [
#  "MTVAwards",
#  "MTVAwards",
#  "RIGHTJUSTxREBEL",
#  "mtvawards",
#  "MTVAwards"
# ]
# [
#  "RT",
#  "@MTV:",
#  "Look!!!",
#  "At!!!",
#  "These!!!"
# ]

# %% [markdown]
# ## Example 7. Creating a basic frequency distribution from the words in tweets

# %%
from collections import Counter

for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print(c.most_common()[:10]) # top 10
    print()
# Out:
# [('RT', 42), ('the', 29), ('#MTVAwards', 28), ('at', 19), ('to', 15), ('for', 15), ('@MTV:', 12), ('a', 12), ('and', 11), ('in', 10)]
#
# [('MTV', 16), ('MTVAwards', 4), ('chloexhalle', 3), ('ladygaga', 3), ('EmmaWatson', 2), ('NubiaSoulGODdes', 2), ('lindsaylohan', 2), ('iamctrex', 2), ('nfrealmusic', 2), ('beamiller', 2)]
#
# [('MTVAwards', 31), ('mtvawards', 10), ('applemusic', 5), ('spotify', 5), ('FirstTakeBoyz', 5), ('tidal', 4), ('complex', 3), ('soul', 3), ('fashion', 3), ('style', 3)]

# %% [markdown]
# ## Example 8. Create a prettyprint function to display tuples in a nice tabular format

# %%
def prettyprint_counts(label, list_of_tuples):
    print("\n{:^20} | {:^6}".format(label, "Count"))
    print("*"*40)
    for k,v in list_of_tuples:
        print("{:20} | {:>6}".format(k,v))

# %%
for label, data in (('Word', words), 
                    ('Screen Name', screen_names), 
                    ('Hashtag', hashtags)):
    
    c = Counter(data)
    prettyprint_counts(label, c.most_common()[:10])
# Out:
#         Word         | Count
# ****************************************
# RT                   |     42
# the                  |     29
# #MTVAwards           |     28
# at                   |     19
# to                   |     15
# for                  |     15
# @MTV:                |     12
# a                    |     12
# and                  |     11
# in                   |     10
#
#     Screen Name      | Count
# ****************************************
# MTV                  |     16
# MTVAwards            |      4
# chloexhalle          |      3
# ladygaga             |      3
# EmmaWatson           |      2
# NubiaSoulGODdes      |      2
# lindsaylohan         |      2
# iamctrex             |      2
# nfrealmusic          |      2
# beamiller            |      2
#
#       Hashtag        | Count
# ****************************************
# MTVAwards            |     31
# mtvawards            |     10
# applemusic           |      5
# spotify              |      5
# FirstTakeBoyz        |      5
# tidal                |      4
# complex              |      3
# soul                 |      3
# fashion              |      3
# style                |      3

# %% [markdown]
# ## Example 9. Finding the most popular retweets

# %%
retweets = [
            # Store out a tuple of these three values ...
            (status['retweet_count'], 
             status['retweeted_status']['user']['screen_name'],
             status['text'].replace("\n","\\")) 
            
            # ... for each status ...
            for status in statuses 
            
            # ... so long as the status meets this condition.
                if 'retweeted_status' in status
           ]

# %%
row_template = "{:^7} | {:^15} | {:50}"
def prettyprint_tweets(list_of_tuples):
    print()
    print(row_template.format("Count", "Screen Name", "Text"))
    print("*"*60)
    for count, screen_name, text in list_of_tuples:
        print(row_template.format(count, screen_name, text[:50]))
        if len(text) > 50:
            print(row_template.format("", "", text[50:100]))
            if len(text) > 100:
                print(row_template.format("", "", text[100:]))

# %%
# Slice off the first 5 from the sorted results and display each item in the tuple

prettyprint_tweets(sorted(retweets, reverse=True)[:10])
# Out:
#  Count  |   Screen Name   | Text
# ************************************************************
#  14589  |    getFANDOM    | RT @getFANDOM: Chris Pratt with all of the wisdom
#         |                 | #MTVAwards https://t.co/eu5cXU7WcQ
#  9883   |    ladygaga     | RT @ladygaga: So happy that #GagaFiveFootTwo won B
#         |                 | est Music Documentary at the #MTVAwards! Thank u L
#         |                 | ittle Monsters &amp; @MTV!! 😘 https://t.co/…
#  8260   |       MTV       | RT @MTV: Let @dylanobrien guide you through a firs
#         |                 | t look at Maze Runner: The Death Cure, exclusively
#         |                 |  for the #MTVAwards tonight at 8/7c! 💥…
#  6099   |       MTV       | RT @MTV: 1 of 9 rules from @prattprattpratt "Don't
#         |                 |  be a 💩" Congrats on receiving the Generation Awar
#         |                 | d! #MTVAwards https://t.co/IFn87o8Kuk
#  6018   |    MTVAwards    | RT @MTVAwards: OH HEYY LITTLE MONSTERS 👋👋👋\The QUE
#         |                 | EN @LadyGaga won Best Music Documentary for ‘Gaga:
#         |                 |  Five Foot Two.’ | Tune into #MTVAwards…
#  6001   |   EmmaWatson    | RT @EmmaWatson: Thank you @MTV for a wonderful eve
#         |                 | ning and thank you to everyone who voted for me! ❤
#         |                 | ️🍿 #MTVAwards @beourguest
#  5281   |  Benji_Mascolo  | RT @Benji_Mascolo: Ho detto tutto. #MTVAwards http
#         |                 | s://t.co/csyoraPWuc
#  4497   |       MTV       | RT @MTV: Thank you for your beautiful Best Actor i
#         |                 | n a Movie acceptance speech at the #MTVAwards, @Em
#         |                 | maWatson 💖 https://t.co/iGN3nQQylL
#  4476   |       MTV       | RT @MTV: My queens @chloexhalle slayed their perfo
#         |                 | rmance at the #MTVAwards 😍 https://t.co/cDZ8kwmkF9
#  3984   |   tylergposey   | RT @tylergposey: last year I wore a onesie, this y
#         |                 | ear who knows? tomorrow's the #mtvawards and I'm t
#         |                 | eaming up w/#ToyotaCHR to make some mis…
